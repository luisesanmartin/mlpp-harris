# %% [markdown]
# # Data exploration
#
# We'll begin by reading in the data

# %%
import pandas as pd
df = pd.read_csv("data/credit-data.csv")

# %% [markdown]
# Checking the column names

# %%
df.columns
# Out:
# Index(['PersonID', 'SeriousDlqin2yrs', 'RevolvingUtilizationOfUnsecuredLines',
#        'age', 'zipcode', 'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio',
#        'MonthlyIncome', 'NumberOfOpenCreditLinesAndLoans',
#        'NumberOfTimes90DaysLate', 'NumberRealEstateLoansOrLines',
#        'NumberOfTime60-89DaysPastDueNotWorse', 'NumberOfDependents'],
#       dtype='object')

# %% [markdown]
# Now we'll check the type of each column

# %%
for col in df.columns:
    print(col, 'is type --->', df[col].dtype)
# Out:
# PersonID is type ---> int64
# SeriousDlqin2yrs is type ---> int64
# RevolvingUtilizationOfUnsecuredLines is type ---> float64
# age is type ---> int64
# zipcode is type ---> int64
# NumberOfTime30-59DaysPastDueNotWorse is type ---> int64
# DebtRatio is type ---> float64
# MonthlyIncome is type ---> float64
# NumberOfOpenCreditLinesAndLoans is type ---> int64
# NumberOfTimes90DaysLate is type ---> int64
# NumberRealEstateLoansOrLines is type ---> int64
# NumberOfTime60-89DaysPastDueNotWorse is type ---> int64
# NumberOfDependents is type ---> float64

# %% [markdown]
# Some columns have float types when they should have int, but for our exploration purposes, all variables have an appropriate numeric type.
#
# Checking the proportion of missing values:

# %%
total = len(df)
for col in df.columns:
    print(col, 'has', df[col].isna().sum() / total, 'as missings proportion')
# Out:
# PersonID has 0.0 as missings proportion
# SeriousDlqin2yrs has 0.0 as missings proportion
# RevolvingUtilizationOfUnsecuredLines has 0.0 as missings proportion
# age has 0.0 as missings proportion
# zipcode has 0.0 as missings proportion
# NumberOfTime30-59DaysPastDueNotWorse has 0.0 as missings proportion
# DebtRatio has 0.0 as missings proportion
# MonthlyIncome has 0.1944119368051492 as missings proportion
# NumberOfOpenCreditLinesAndLoans has 0.0 as missings proportion
# NumberOfTimes90DaysLate has 0.0 as missings proportion
# NumberRealEstateLoansOrLines has 0.0 as missings proportion
# NumberOfTime60-89DaysPastDueNotWorse has 0.0 as missings proportion
# NumberOfDependents has 0.02528281646186854 as missings proportion

# %% [markdown]
# `MonthlyIncome` has 19.4% of observations with missing values and `NumberOfDependents` has 2.5%. This will cause us to lose a non-trivial number of observations when conducting our analysis. To avoid this, we'll have to conduct some kind of imputation rule in these cases later on.
#
# Tabulating the target attribute:

# %%
df.groupby('SeriousDlqin2yrs').size()
# Out:
# SeriousDlqin2yrs
# 0    34396
# 1     6620
# dtype: int64

# %% [markdown]
# We see that our dataframe has 34396 + 6620 = 41016 observations. 16% of observations have a value of one for the variable `SeriousDlqin2yrs`.
#
# Now we'll graph a correlation matrix color map to know which of the variables we have are correlated with the target attribute.

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow0_col2 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow0_col3 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow0_col4 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow0_col6 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow0_col7 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow0_col8 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow0_col9 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow0_col10 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow0_col11 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow0_col12 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow1_col2 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow1_col3 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow1_col5 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow1_col6 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow1_col8 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow1_col9 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow1_col10 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow1_col11 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow1_col12 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow2_col0 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow2_col1 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow2_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow2_col4 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow2_col5 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow2_col6 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow2_col7 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow2_col8 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow2_col9 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow2_col10 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow2_col11 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow2_col12 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow3_col0 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow3_col1 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow3_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow3_col4 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow3_col5 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow3_col6 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow3_col7 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow3_col8 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow3_col9 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow3_col10 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow3_col11 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow3_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow4_col0 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow4_col1 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow4_col2 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow4_col3 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow4_col5 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow4_col6 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_543a02dc_5f20_11e9_9fac_ace010a3f66brow4_col7 {
#             background-color:  #4257c9;
#             color:

# %% [markdown]
# Surprisingly, the variable with the highest correlation with `SeriousDlqin2yrs` is `PersonID`. As the data dictionary provided doesn't include any explanation of how the ID was assigned, we'll assume this correlation is spurious. Appart from that, the variable with the highest correlation with `SeriousDlqin2yrs` is `age`. In general, none variable has a remarkably high correlation with our target attribute, and all of them seem to have similarly low correlation levels.
